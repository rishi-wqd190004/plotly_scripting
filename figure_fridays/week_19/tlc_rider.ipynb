# %%
import pandas as pd

import dash

# %%
df = pd.read_csv('dataset/TLC_New_Driver_Application.csv')

# %%
df.head()
# Out:
#     App No Type  App Date                     Status FRU Interview Scheduled  \
# 0  6102537  HDR  1/1/2025                     Denied          Not Applicable
# 1  6102605  HDR  1/2/2025  Approved - License Issued          Not Applicable
# 2  6102618  HDR  1/2/2025  Approved - License Issued          Not Applicable
# 3  6102662  HDR  1/3/2025                     Denied          Not Applicable
# 4  6102670  HDR  1/3/2025                     Denied          Not Applicable
#
#   Drug Test WAV Course Defensive Driving Driver Exam Medical Clearance Form  \
# 0  Complete   Complete            Needed    Complete               Complete
# 1  Complete   Complete          Complete    Complete               Complete
# 2  Complete   Complete          Complete    Complete               Complete
# 3  Complete   Complete            Needed      Needed               Complete
# 4  Complete   Complete            Needed    Complete                 Needed
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3334 entries, 0 to 3333
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   App No                   3334 non-null   int64
#  1   Type                     3334 non-null   object
#  2   App Date                 3334 non-null   object
#  3   Status                   3334 non-null   object
#  4   FRU Interview Scheduled  3334 non-null   object
#  5   Drug Test                3334 non-null   object
#  6   WAV Course               3334 non-null   object
#  7   Defensive Driving        3334 non-null   object
#  8   Driver Exam              3334 non-null   object
#  9   Medical Clearance Form   3334 non-null   object
#  10  Other Requirements       3334 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 286.6+ KB

# %%
for col in df.columns:
    print(col)
    print(df[col].value_counts())
    print("*" * 20)
# Out:
# App No
# App No
# 6109655    2
# 6102537    1
# 6108292    1
# 6108244    1
# 6108251    1
#           ..
# 6106472    1
# 6106562    1
# 6106561    1
# 6106527    1
# 6109721    1
# Name: count, Length: 3333, dtype: int64
# ********************
# Type
# Type
# HDR    3320
# VDR       9
# PDR       5
# Name: count, dtype: int64
# ********************
# App Date
# App Date
# 4/14/2025    94
# 4/7/2025     91
# 4/21/2025    84
# 4/28/2025    71
# 4/16/2025    59
#              ..
# 1/8/2025      2
# 1/4/2025      2
# 1/3/2025      2
# 1/9/2025      1
# 1/1/2025      1
# Name: count, Length: 123, dtype: int64
# ********************
# Status
# Status
# Incomplete                   2569
# Approved - License Issued     515
# Denied                        158
# Under Review                   86
# Pending Fitness Interview       6
# Name: count, dtype: int64
# ********************
# FRU Interview Scheduled
# FRU Interview Scheduled
# Not Applicable    3325
# 4/1/2025             1
# ...
