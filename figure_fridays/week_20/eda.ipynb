# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../datasets_all/nation-dams.csv')
df.shape
# Out:
# (10186, 48)

# %%
df.head()
# Out:
#                  Dam Name   NID ID                              Owner Names  \
# 0     Aichi Forge Usa Dam  KY00728                                    AICHI
# 1  Oxy Usa Retention Pond  ND01160                             OXY USA Inc.
# 2               Dod Usa 4  OK20998  DEPT. OF DEFENSE/US ARMY RESERVE CENTER
# 3               Dod Usa 2  OK20994  DEPT. OF DEFENSE/US ARMY RESERVE CENTER
# 4  Girl Scouts of Usa Dam  NC02637  Girl Scouts, Carolina Peaks to Piedmont
#
#   Primary Owner Type                               Designer Names  \
# 0            Private  AUSTIN ENGINEERS, INC. SOUTHFIELD, MICHIGAN
# 1            Private                     Jerrel S. Krieg, PE-4530
# 2            Federal                                          NaN
# 3            Federal                                          NaN
# 4            Private                                          NaN
#
#   Non-Federal Dam on Federal Property Primary Purpose   Latitude   Longitude  \
# ...

# %%
df[df['Owner Names'] == 'AICHI']
# Out:
#               Dam Name   NID ID Owner Names Primary Owner Type  \
# 0  Aichi Forge Usa Dam  KY00728       AICHI            Private
#
#                                 Designer Names  \
# 0  AUSTIN ENGINEERS, INC. SOUTHFIELD, MICHIGAN
#
#   Non-Federal Dam on Federal Property Primary Purpose  Latitude  Longitude  \
# 0                                 NaN           Other  38.28828  -84.55619
#
#       State County            City  Distance to Nearest City (Miles)  \
# 0  Kentucky  Scott  DELAPLAIN-AREA                               1.0
#
#                 Congressional District  \
# 0  Kentucky, Congressional District 06
#
#   American Indian/Alaska Native/Native Hawaiian State Regulated Dam  \
# 0                                           NaN                 Yes
#
#   Federally Regulated Dam  Dam Height (Ft)  Hydraulic Height (Ft)  \
# 0                      No             15.0                    NaN
#
#    Structural Height (Ft)  NID Height (Ft) NID Height Category  \
# ...

# %%
df.columns
# Out:
# Index(['Dam Name', 'NID ID', 'Owner Names', 'Primary Owner Type',
#        'Designer Names', 'Non-Federal Dam on Federal Property',
#        'Primary Purpose', 'Latitude', 'Longitude', 'State', 'County', 'City',
#        'Distance to Nearest City (Miles)', 'Congressional District',
#        'American Indian/Alaska Native/Native Hawaiian', 'State Regulated Dam',
#        'Federally Regulated Dam', 'Dam Height (Ft)', 'Hydraulic Height (Ft)',
#        'Structural Height (Ft)', 'NID Height (Ft)', 'NID Height Category',
#        'Dam Length (Ft)', 'Volume (Cubic Yards)', 'Year Completed',
#        'Year Completed Category', 'Years Modified', 'NID Storage (Acre-Ft)',
#        'Max Storage (Acre-Ft)', 'Normal Storage (Acre-Ft)',
#        'Surface Area (Acres)', 'Drainage Area (Sq Miles)',
#        'Max Discharge (Cubic Ft/Second)', 'Spillway Type',
#        'Spillway Width (Ft)', 'Outlet Gate Type', 'Data Last Updated',
#        'Last Inspection Date', 'Inspection Frequency',
# ...

# %%
df['State'].value_counts()
# Out:
# State
# Virginia          1166
# Oklahoma          1114
# Texas              950
# North Carolina     935
# Iowa               709
# Ohio               620
# Massachusetts      501
# Kentucky           474
# Nebraska           406
# Mississippi        405
# Kansas             402
# Utah               382
# New Jersey         370
# New Hampshire      239
# Colorado           195
# Wyoming            157
# California         150
# North Dakota       109
# Georgia             86
# Arkansas            74
# Louisiana           69
# Oregon              67
# Montana             58
# South Carolina      53
# Pennsylvania        47
# Indiana             43
# Wisconsin           43
# Nevada              42
# Arizona             36
# Missouri            35
# Illinois            33
# Connecticut         28
# South Dakota        26
# New York            23
# New Mexico          21
# Maine               19
# Idaho               18
# Minnesota           16
# Washington          13
# ...

# %%
df['Hazard Potential Classification'].value_counts()
# Out:
# Hazard Potential Classification
# Low             5235
# High            2613
# Significant     1532
# Undetermined     806
# Name: count, dtype: int64

# %%
df['Inspection Frequency'].value_counts()
# Out:
# Inspection Frequency
# 5.0     3335
# 1.0      864
# 2.0      759
# 3.0      428
# 6.0      344
# 4.0      278
# 10.0     188
# 0.0       58
# 0.5        7
# 12.0       6
# 7.0        6
# 8.0        3
# 2.5        1
# Name: count, dtype: int64

# %%
df['Volume (Cubic Yards)'].value_counts()
# Out:
# Volume (Cubic Yards)
# 0.0         1329
# 100.0         48
# 50000.0       11
# 100000.0      10
# 40000.0        9
#             ...
# 111600.0       1
# 121060.0       1
# 47230.0        1
# 43480.0        1
# 1325.0         1
# Name: count, Length: 2825, dtype: int64

# %%
df['Non-Federal Dam on Federal Property'].value_counts()
# Out:
# Non-Federal Dam on Federal Property
# No     4713
# Yes     598
# Name: count, dtype: int64

# %%
df['Primary Owner Type'].value_counts()
# Out:
# Primary Owner Type
# Local Government    4540
# Private             3156
# State               1662
# Not Listed           336
# Federal              314
# Public Utility       178
# Name: count, dtype: int64

# %%
df['Dam Name'].value_counts()
# Out:
# Dam Name
# Mill Pond Dam                             12
# Frd No 15                                 10
# Frd No 4                                   9
# Frd No 7                                   9
# Frd No 14                                  9
#                                           ..
# Village Walker Creek WS SCS Site 7 Dam     1
# Centerville City Erosion Dike              1
# Clear Creek WS SCS Sed Cont Str 106        1
# Amelia County Dam # 9                      1
# Winnetuxet Road Pond Dam                   1
# Name: count, Length: 9672, dtype: int64

# %%
df['Dam Height (Ft)'].value_counts()
# Out:
# Dam Height (Ft)
# 25.0     361
# 30.0     325
# 27.0     312
# 26.0     312
# 28.0     302
#         ...
# 410.0      1
# 131.0      1
# 185.0      1
# 202.0      1
# 150.0      1
# Name: count, Length: 143, dtype: int64

# %%
df.isna().sum()
# Out:
# Dam Name                                          126
# NID ID                                              0
# Owner Names                                       619
# Primary Owner Type                                  0
# Designer Names                                   3967
# Non-Federal Dam on Federal Property              4875
# Primary Purpose                                   400
# Latitude                                            4
# Longitude                                           4
# State                                               0
# County                                              3
# City                                             3214
# Distance to Nearest City (Miles)                 4871
# Congressional District                              5
# American Indian/Alaska Native/Native Hawaiian    9034
# State Regulated Dam                                 0
# Federally Regulated Dam                             0
# ...

# %%
df['Structural Height (Ft)'] = df['Dam Height (Ft)'].fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df['Dam Height (Ft)'] = df['Dam Height (Ft)'].fillna()
#
# File ~/miniconda3/envs/plotly_venv/lib/python3.12/site-packages/pandas/core/generic.py:7293, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7286         if ctr <= ref_count:
#    7287             warnings.warn(
#    7288                 _chained_assignment_warning_method_msg,
#    7289                 FutureWarning,
#    7290                 stacklevel=2,
#    7291             )
# -> 7293 value, method = validate_fillna_kwargs(value, method)
#    7294 if method is not None:
#    7295     warnings.warn(
#    7296         f"{type(self).__name__}.fillna with 'method' is deprecated and "
#    7297         "will raise in a future version. Use obj.ffill() or obj.bfill() "
#    (...)
# ...
