# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('/Users/rishi/plotly_scripting/figure_fridays/week_30/dataset/europe_monthly_electricity.csv')
df.head(2)
# Out:
#       Area ISO 3 code        Date           Area type Continent Ember region  \
# 0  Austria        AUT  2015-01-01  Country or economy    Europe       Europe
# 1  Austria        AUT  2015-01-01  Country or economy    Europe       Europe
#
#     EU  OECD  G20   G7  ASEAN                Category     Subcategory  \
# 0  1.0   1.0  0.0  0.0    0.0      Electricity demand          Demand
# 1  1.0   1.0  0.0  0.0    0.0  Electricity generation  Aggregate fuel
#
#   Variable Unit  Value  YoY absolute change  YoY % change
# 0   Demand  TWh   7.58                  NaN           NaN
# 1    Clean    %  69.64                  NaN           NaN

# %%
emissions_df = df[
        ((df['Category'].str.contains('emission', case=False, na=False)) |
         (df['Variable'].str.contains('emission', case=False, na=False))) &
        (df['Area'] == 'Austria')]

# %%
# To get all rows with the maximum value
max_rows = emissions_df[emissions_df['Value'] == emissions_df['Value'].max()]
max_rows
# Out:
#          Area ISO 3 code        Date           Area type Continent  \
# 1216  Austria        AUT  2017-01-01  Country or economy    Europe
#
#      Ember region   EU  OECD  G20   G7  ASEAN                Category  \
# 1216       Europe  1.0   1.0  0.0  0.0    0.0  Power sector emissions
#
#         Subcategory       Variable           Unit   Value  \
# 1216  CO2 intensity  CO2 intensity  gCO2e per kWh  266.67
#
#       YoY absolute change  YoY % change
# 1216                  NaN           NaN
